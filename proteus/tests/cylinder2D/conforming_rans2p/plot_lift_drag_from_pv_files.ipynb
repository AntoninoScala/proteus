# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
directory="./"
# !ls
# Out:
# comparison_files    plot_lift_drag_from_pv_files.ipynb
# cylinder2D.1.neigh  plot_lift_drag_from_pv_files.ipynb.tmp
# cylinder2D.1.poly   __pycache__
# cylinder2D.edge     README.md
# cylinder2D.ele	    symmetricDomain_john.py
# cylinder2D.node     symmetricDomain_john.pyc
# cylinder2D.ply	    test_cylinder2D_conforming_rans2p.py
# cylinder2D.poly     timeHistory.txt
# cylinder2d.py	    TimeList.txt
# cylinder2d.pyc	    top_right.1.edge
# cylinder.h5	    top_right.1.ele
# cylinder_so.log     top_right.1.neigh
# cylinder_so.py	    top_right.1.node
# cylinder_so.pyc     top_right.1.poly
# cylinder.xmf	    top_right.poly
# forceHistory_p.txt  twp_navier_stokes_cylinder_2d_n.py
# forceHistory_v.txt  twp_navier_stokes_cylinder_2d_n.pyc
# __init__.py	    twp_navier_stokes_cylinder_2d_p.py
# __init__.pyc	    twp_navier_stokes_cylinder_2d_p.pyc
# momentHistory.txt   wettedAreaHistory.txt
# petsc.options

# %%
p_force = np.genfromtxt(directory+"forceHistory_p.txt", dtype=float)
v_force = np.genfromtxt(directory+"forceHistory_v.txt", dtype=float)

# %%
force=p_force+v_force

# %%
print(force.shape)
# Out:
# (2000, 3)

# %%
N = force.shape[0]

# %%
plt.plot(range(N), force[:,0], 'b', range(N),force[:,1], 'y')
plt.axis([0, N, -.05, 0.25])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
D = 0.1
U = 1.0
rho=1.0
Cd = force[:,0]*2/rho/D/U/U
Cl = force[:,1]*2/rho/D/U/U

# %%
plt.figure()
p1, = plt.plot(range(N), Cd, 'b', label='Cd')
p2, = plt.plot(range(N), Cl, 'y', label='Cl')
plt.axis([0, N, -1, 4])
plt.legend(handles=[p1,p2])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Cd[-100:].sum()/100.0
# Out:
# 3.135353036571911

# %%
Cl[:].min()
# Out:
# -0.713037828743447
